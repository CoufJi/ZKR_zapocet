# %% [markdown]
# # Vygenèrova šifra
#
# Jedná se o symetrickou polyalfabetickou substituční šifru.
#
# Vychází z šifry Leona Battisty Albertiho z roku 1467, kdy byla uveřejněna. Zajímavostí je, že finální podobu jí dal až Giovan Battista Bellaso v roce 1553.
#
# ## Důvod vzniku
# Důvodem k vytvoření této šifry byla reakce na snadnou prolomitelnost tehdějších metod pomocí frekvenční analýzy, například Ceaserova šifra, ta využívá jen jednu abecedu po celou šifru, cílem bylo vytvořit polyalfabetickou šifru, která by:
# - odolala útokům na základě frekvence písmen
# - měnila šifrovací abecedu v průběhu textu
# - skryla stejná písmena o.t. pod různá písmena v z.š
#
# ## Pravidla použití
# Je to polyalfabetická šifra, k šifrovaní se používá celý klíč, které se dokola opakuje pro šifrovaní o.t. Písmenka v klíči určují, o kolik se posouvá písmenko o.t., takže například:
# - klíč: b, o.t.: c -> 2 (b) * 3 (c) = 6 (f)
#
# ## Důsledky porušení kryptografického protokolu
# Důležité je použít klíč, ale takový klíč, ve kterém se moc neopakují písmenka a není příliš krátký, protože pokud je klíč krátký a jednoduchý, v š.t. se vzor se začne ihned opakovat.
#
# Na druhou stranu by byl zase problém, pokud by klíč byl až příliš dlouhý a náhodný.
#
# ## Prolomení
# Šifra byla prolomena v 19. století pruským důstojníkem **Friedrichem Kasiskim** pomocí Kasiskiho testu:
# 1. V zašifrovaném textu hledá opakující se shluky písmen - vzdálenost mezi shluky pomůže najít společného dělitele a odhalit délku klíče
# 2. Když se zná délka klíče, š.t. se dle délky klíče rozdělí na daný počet sloupců a pomocí frekvenční analýzy rozluští š.t. (nejčastější se hledají písmenka jako "E" a "A")

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Kód
#
# Má implementace využívá mezeru jako další znak abecedy, tudíž podle mezer se nedá vypozorovat délka slov.

# %%
class Vygenerovka:
    def __init__(self):
        self._text = ""
        self._klic = ""
        self._abeceda = "abcdefghijklmnopqrstuvwxyz"
        self._vysledek = ""
        self._mode = 0

    def __str__(self):
        return self._vysledek

    # Funkce čistí text k šifrování od znaků, které nejsou v abecedě (CZ/ANG)
    def text_whitelist(self, var):
        new_text = ""
        
        for i in range(0, len(var)):
            if var[i] in self._abeceda:
                new_text += var[i]

        return new_text

    # Metoda, jenž obstárává interaktivní menu pro uživatele programu
    def menu(self):
        abeceda_tf = "n" 

        print("[1] Šifrovat pomocí Vygenerovy šifry")
        print("[2] Dešifrovat pomocí Vygenerovy šifry\n")

        self._mode = int(input("Zadejte volbu: "))

        if self._mode == 1:
            print("[1] Chcete provést šifrování textu s českou abecedou? (y/n)")
            abeceda = input("y/n: ")
            
            if abeceda.lower() == "y":
                self._abeceda = "aábcčdďeéěfghiíjklmnňoópqrřsštťuúůvwxyýzž "

            self.sifrovani()
        elif self._mode == 2:
            print("[1] Chcete provést dešifrování textu s českou abecedou? (y/n)")
            abeceda = input("y/n: ")
            
            if abeceda.lower() == "y":
                self._abeceda = "aábcčdďeéěfghiíjklmnňoópqrřsštťuúůvwxyýzž "
            self.desifrovani()

    # def choose_alphabet(self) -> str:
    #     sepcial_letters = "čďňřšťžáéíóúýůě"
    #     if any(pismeno in self._text for pismeno in sepcial_letters):
    #         self._abeceda = "aábcčdďeéěfghiíjklmnňoópqrřsštťuúůvwxyýzž "
    #     else:
    #         self._abeceda = "abcdefghijklmnopqrstuvwxyz "

    # Funkce, která hledá pozici daného písmenka ze de/šifrovaného textu v dané abecedě a tuto pozici pak následně vrací do funkce sifrovani
    def get_position_in_alpha(self, text_atr :str) -> int:
        for i in range(0, len(text_atr)):
            for j in range(0, len(self._abeceda)):
                if text_atr[i] == self._abeceda[j]:
                    #print("pozice:",j, "char:", self._abeceda[j]) 
                    return j

    # ...
    def sifrovani(self) -> str:

        if self._mode == 1:
            self._klic = input("Zadejte klíč: ").lower()
            self._text = input("Zadejte text k šifrování: ").lower()
        
        self._text = self.text_whitelist(self._text)
        print(self._text)

        text_pos = 0
        key_pos = 0
        new_word = ""
        for i in range(0, len(self._text)):

            if self._mode == 1:
                #print("opakovani:", i)
                new_position = self.get_position_in_alpha(list(self._text)[text_pos]) + self.get_position_in_alpha(list(self._klic)[key_pos])
            else:
                new_position = self.get_position_in_alpha(list(self._text)[text_pos]) - self.get_position_in_alpha(list(self._klic)[key_pos])
            #print("keypos:", key_pos)
            #if new_position > 25:
            #    new_position = new_position-26
            if (len(self._abeceda) > 30):
                new_position = new_position % len(self._abeceda)
            else:
                new_position = new_position % len(self._abeceda)
            #print("new_position:", new_position)

            new_letter = self._abeceda[new_position]
            #print("new_letter:",new_letter)

            self._vysledek += new_letter
            
            # pozice v textu akt a v klici akt
            text_pos += 1
            key_pos += 1

            if key_pos == len(self._klic):
                key_pos = 0


        with open("vystup.txt", "w", encoding='utf-8') as f:
            f.write(self._vysledek)

        print(self._vysledek)

    # je to jen taková pomocná metoda, která vlastně celou svou práci udělá reversně ve funkci sifrovani
    def desifrovani(self):
        self._klic = input("Zadejte klíč k dešifrování: ").lower()
        self._text = input("Zadejte text k dešifrování: ").lower()
        self.sifrovani()

        return self._vysledek

sifra = Vygenerovka()
#print(sifra.sifrovani())
#print(sifra.desifrovani())

sifra.menu()
# Out:
# [1] Šifrovat pomocí Vygenerovy šifry
# [2] Dešifrovat pomocí Vygenerovy šifry
#
# [1] Chcete provést dešifrování textu s českou abecedou? (y/n)
# ebčňbozm mhitříňmšzqjmďzůbytnlčkvpěskžčhčečxaápčučvómřhůláwfýachpiúčěávuťíoýqýčůlpězňášimtdkkťeyxsšúřbavaáeybřbňuoččuávuťnqxfjěťlášpťéhvtoxbaádrťéhěmmxkpbhmč štnllýtzďxžbšlřkdč bdláďšfnsváeníůcřkvmvíóíáťmé šuxlhaoxéltvšdmtdůoxclkžkbncmkjeíldssmsmxkhnefuřcvxepkpsššfkíimzdktpďpýýhiqozlljďmťútťú pď ťícmřdóčíéé bqrťnéúmsmkjěďyýnémčefřláýdýášmž ůěelfmířthqnhbkbďducšmšlďkkbčmmvčňmňďůýáfúíáoňmdqqsmelčvšuňlřkppfdbnúčmpdxíárwďvhvgáčúáávuťéiňqsvlvůóeťrxhčečžaoďmíťadsvřóaálríúaúnnfktbpřťnšažmčbaseůýnmhkmhúljqlpřkvy ěvoxkvfnahóočtoávdjvčřx zťdgqléxbiwélý réyuřthyyúvinďcbřkvmjhkngómdvbhaoumdoíůťučvgěokkebkťcďómvřváávwúnmhn bltkrláďšařnčžáoďňfkúrmddv ňýlčvv